# %% [markdown]
# The INDRA Network Service can be used to programmatically search for paths in
# the indra network.
#
# First, you need to start the server (assuming you have all
# [prerequisites](https://github.com/indralab/depmap_analysis/blob/master/doc/indra_depmap_service/depmap_service.rst)).
#
# Assuming you run the server with default parameters `python api.py`, you
# should have access to a POST endpoint on `http://localhost/query/submit`.
#
# Read about the available search options in the docstring of
# `IndraNetwork.handle_query()` in `depmap_analysis/network_functions/indra_network.py`.
#
# Below we search for paths from `BRCA1` to `BRCA2` with a maximum path length
# of 4 edges (maximum allowed), `'CHEBI', 'FPLX', 'GO', 'HGNC', 'HMDB',
# 'MESH'` and `'PUBCHEM'` as allowed node namespaces and `'activation',
# 'increaseamount', 'phosphorylation'` as allowed statement types in the edges
# of the path.

# %%
import requests
from pprint import pprint
 
submit_url = 'http://localhost:5000/query/submit'
source = 'BRCA1'
target = 'BRCA2'
search_options = {'source': 'BRCA1', 
                  'target': 'BRCA2', 
                  'stmt_filter': ['fplx', 'complex'], 
                  'edge_hash_blacklist': [], 
                  'node_filter': ['hgnc', 'fplx'], 
                  'node_blacklist': [], 
                  'path_length': False, 
                  'weighted': False, 
                  'bsco': 0, 
                  'curated_db_only': False, 
                  'fplx_expand': False, 
                  'k_shortest': 3}

path_results = requests.post(url=submit_url, json=search_options).json()
pprint(path_results)
# Out:
# {'result': {'common_parents': {'common_parents': ['http://identifiers.org/fplx/BRCA',
#                                                   'http://identifiers.org/fplx/FANC'],
#                                'source_id': '1100',
#                                'source_ns': 'HGNC',
#                                'target_id': '1101',
#                                'target_ns': 'HGNC'},
#             'common_targets': [{'RAD51': [[{'bs': 0.9989832499999994,
#                                             'curated': False,
#                                             'evidence': {'medscan': 4,
#                                                          'reach': 23,
#                                                          'sparser': 1},
#                                             'evidence_count': 28,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '-30921056343130233',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.0010173673426981124},
#                                            {'bs': 0.98249311095,
#                                             'curated': False,
#                                             'evidence': {'medscan': 1,
#                                                          'reach': 9},
#                                             'evidence_count': 10,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '-2632961531538256',
#                                             'stmt_type': 'Inhibition',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.01766204880091767},
#                                            {'bs': 0.8775000000000001,
#                                             'curated': False,
#                                             'evidence': {'medscan': 1,
#                                                          'reach': 1},
#                                             'evidence_count': 2,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '-17748516137414794',
#                                             'stmt_type': 'DecreaseAmount',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.1306784376022365},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'medscan': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '31035824227561695',
#                                             'stmt_type': 'DecreaseAmount',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '-24253955741230142',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '18739513311363648',
#                                             'stmt_type': 'Inhibition',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '4869762729221149',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '20888164426609675',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198}],
#                                           [{'bs': 0.9975,
#                                             'curated': False,
#                                             'evidence': {'medscan': 37,
#                                                          'reach': 135},
#                                             'evidence_count': 172,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '32544654866504942',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.0025032304687500158},
#                                            {'bs': 0.99749901585,
#                                             'curated': False,
#                                             'evidence': {'medscan': 9,
#                                                          'reach': 38},
#                                             'evidence_count': 47,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '31912864625416945',
#                                             'stmt_type': 'Inhibition',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.002504217085877034},
#                                            {'bs': 0.996953817,
#                                             'curated': False,
#                                             'evidence': {'medscan': 5,
#                                                          'reach': 4},
#                                             'evidence_count': 9,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '35501421202953123',
#                                             'stmt_type': 'DecreaseAmount',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.0030509323646458818},
#                                            {'bs': 0.98922,
#                                             'curated': False,
#                                             'evidence': {'medscan': 3,
#                                                          'reach': 2},
#                                             'evidence_count': 5,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '-22137682331517652',
#                                             'stmt_type': 'Inhibition',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.0108386262707474},
#                                            {'bs': 0.951,
#                                             'curated': False,
#                                             'evidence': {'medscan': 2,
#                                                          'reach': 1},
#                                             'evidence_count': 3,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '7962214570147879',
#                                             'stmt_type': 'IncreaseAmount',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.05024132158922335},
#                                            {'bs': 0.8775000000000001,
#                                             'curated': False,
#                                             'evidence': {'rlimsp': 1,
#                                                          'sparser': 1},
#                                             'evidence_count': 2,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '-13991607282809105',
#                                             'stmt_type': 'Phosphorylation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.1306784376022365},
#                                            {'bs': 0.86,
#                                             'curated': False,
#                                             'evidence': {'reach': 2},
#                                             'evidence_count': 2,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '25763215093906257',
#                                             'stmt_type': 'Inhibition',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.1508230060136601},
#                                            {'bs': 0.86,
#                                             'curated': False,
#                                             'evidence': {'reach': 2},
#                                             'evidence_count': 2,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '23773181544149516',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.1508230060136601},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '27909238850029512',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '15375120662438550',
#                                             'stmt_type': 'IncreaseAmount',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '34937385574316999',
#                                             'stmt_type': 'DecreaseAmount',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '32116835312705726',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'medscan': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '-2440264198753635',
#                                             'stmt_type': 'DecreaseAmount',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '3862806327277658',
#                                             'stmt_type': 'Inhibition',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '-9905851700534041',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'RAD51',
#                                             'stmt_hash': '-30204848302926906',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198}]],
#                                 'lowest_highest_belief': 0.9975},
#                                {'STK11': [[{'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'STK11',
#                                             'stmt_hash': '-4942758577286847',
#                                             'stmt_type': 'Inhibition',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'STK11',
#                                             'stmt_hash': '-4804171823136311',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'STK11',
#                                             'stmt_hash': '11848580307621092',
#                                             'stmt_type': 'IncreaseAmount',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198}],
#                                           [{'bs': 0.65,
#                                             'curated': False,
#                                             'evidence': {'reach': 1},
#                                             'evidence_count': 1,
#                                             'obj': 'STK11',
#                                             'stmt_hash': '34420819783500309',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198}]],
#                                 'lowest_highest_belief': 0.65},
#                                {'Cohesin': [[{'bs': 0.65,
#                                               'curated': False,
#                                               'evidence': {'reach': 1},
#                                               'evidence_count': 1,
#                                               'obj': 'Cohesin',
#                                               'stmt_hash': '2480940089430091',
#                                               'stmt_type': 'Inhibition',
#                                               'subj': 'BRCA1',
#                                               'weight': 0.4307830699386198}],
#                                             [{'bs': 0.65,
#                                               'curated': False,
#                                               'evidence': {'reach': 1},
#                                               'evidence_count': 1,
#                                               'obj': 'Cohesin',
#                                               'stmt_hash': '-35910511173891985',
#                                               'stmt_type': 'Activation',
#                                               'subj': 'BRCA2',
#                                               'weight': 0.4307830699386198}]],
#                                 'lowest_highest_belief': 0.65}],
#             'paths_by_node_count': {'2': [{'cost': '9.9746599868666408425e-18',
#                                            'path': ['BRCA1', 'BRCA2'],
#                                            'sort_key': '0.99999999999999999',
#                                            'stmts': [[{'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '30554531605300833',
#                                                        'stmt_type': 'Inhibition',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.979665,
#                                                        'curated': False,
#                                                        'evidence': {'medscan': 1,
#                                                                     'reach': 4},
#                                                        'evidence_count': 5,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '17829736942076414',
#                                                        'stmt_type': 'Inhibition',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.020544704567422845},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'sparser': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-13592368835625351',
#                                                        'stmt_type': 'Methylation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'medscan': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-24434596336395778',
#                                                        'stmt_type': 'DecreaseAmount',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-12566398630296749',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.97305,
#                                                        'curated': False,
#                                                        'evidence': {'medscan': 3,
#                                                                     'reach': 1},
#                                                        'evidence_count': 4,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '19595309910344099',
#                                                        'stmt_type': 'IncreaseAmount',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.027319913424610057},
#                                                       {'bs': 0.94999995217031,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 14},
#                                                        'evidence_count': 14,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '14631716667987313',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.05129344999776262}]]}],
#                                     '3': [{'cost': '0.008167261466637593325',
#                                            'path': ['BRCA1', 'AKT', 'BRCA2'],
#                                            'sort_key': '0.99999999999999999995',
#                                            'stmts': [[{'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '-34869341311617902',
#                                                        'stmt_type': 'DecreaseAmount',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '985466650257787',
#                                                        'stmt_type': 'Dephosphorylation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.9996892738665496,
#                                                        'curated': False,
#                                                        'evidence': {'medscan': 6,
#                                                                     'reach': 11,
#                                                                     'sparser': 1,
#                                                                     'trips': 1},
#                                                        'evidence_count': 19,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '-12863651045836775',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.0003108744499052366},
#                                                       {'bs': 0.99174,
#                                                        'curated': True,
#                                                        'evidence': {'reach': 1,
#                                                                     'signor': 1},
#                                                        'evidence_count': 2,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '27545891555630417',
#                                                        'stmt_type': 'DecreaseAmount',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.008294403657704725},
#                                                       {'bs': 0.923,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 3},
#                                                        'evidence_count': 3,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '21074602623343237',
#                                                        'stmt_type': 'Dephosphorylation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.08012615282165253},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '-28534121389322269',
#                                                        'stmt_type': 'Dephosphorylation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '31281639495506944',
#                                                        'stmt_type': 'Dephosphorylation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '5601333752317853',
#                                                        'stmt_type': 'DecreaseAmount',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '17850775005158677',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '-14929659018378526',
#                                                        'stmt_type': 'Phosphorylation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '11575308231380717',
#                                                        'stmt_type': 'Deubiquitination',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.94757,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '-33084617137276316',
#                                                        'stmt_type': 'Phosphorylation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.053854571659584675},
#                                                       {'bs': 0.923,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 3},
#                                                        'evidence_count': 3,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '-16594131070504859',
#                                                        'stmt_type': 'Phosphorylation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.08012615282165253},
#                                                       {'bs': 0.941,
#                                                        'curated': True,
#                                                        'evidence': {'signor': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '-24872229365875770',
#                                                        'stmt_type': 'Ubiquitination',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.06081224566668868},
#                                                       {'bs': 0.9929999998192037,
#                                                        'curated': False,
#                                                        'evidence': {'medscan': 2,
#                                                                     'reach': 17},
#                                                        'evidence_count': 19,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '899050533742044',
#                                                        'stmt_type': 'Inhibition',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.007024715823974806},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'AKT',
#                                                        'stmt_hash': '14199834701550702',
#                                                        'stmt_type': 'IncreaseAmount',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198}],
#                                                      [{'bs': 0.9419,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 4},
#                                                        'evidence_count': 4,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-1521547564711959',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'AKT',
#                                                        'weight': 0.059856273321754284},
#                                                       {'bs': 0.86,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 2},
#                                                        'evidence_count': 2,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-4711943486111391',
#                                                        'stmt_type': 'Inhibition',
#                                                        'subj': 'AKT',
#                                                        'weight': 0.1508230060136601}]]},
#                                           {'cost': '0.00017310607334213091678',
#                                            'path': ['BRCA1', 'MRE11', 'BRCA2'],
#                                            'sort_key': '0.99999999999999998265',
#                                            'stmts': [[{'bs': 0.997091188059,
#                                                        'curated': False,
#                                                        'evidence': {'medscan': 4,
#                                                                     'reach': 8},
#                                                        'evidence_count': 12,
#                                                        'obj': 'MRE11',
#                                                        'stmt_hash': '-27823327616500779',
#                                                        'stmt_type': 'Inhibition',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.002913151048128997},
#                                                       {'bs': 0.923,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 3},
#                                                        'evidence_count': 3,
#                                                        'obj': 'MRE11',
#                                                        'stmt_hash': '15505201700712950',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.08012615282165253}],
#                                                      [{'bs': 0.97305,
#                                                        'curated': False,
#                                                        'evidence': {'medscan': 1,
#                                                                     'reach': 3},
#                                                        'evidence_count': 4,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-3430042855573584',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'MRE11',
#                                                        'weight': 0.027319913424610057},
#                                                       {'bs': 0.94757,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 5},
#                                                        'evidence_count': 5,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '17206318823527169',
#                                                        'stmt_type': 'Inhibition',
#                                                        'subj': 'MRE11',
#                                                        'weight': 0.053854571659584675},
#                                                       {'bs': 0.65,
#                                                        'curated': False,
#                                                        'evidence': {'reach': 1},
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-17833579678403738',
#                                                        'stmt_type': 'Phosphorylation',
#                                                        'subj': 'MRE11',
#                                                        'weight': 0.4307830699386198}]]}]},
#             'timeout': False}}
