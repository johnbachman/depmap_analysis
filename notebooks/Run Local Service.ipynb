# %% [markdown]
# The INDRA DepMap Service can be used to programmatically search for paths in
# the indra network.
#
# First, you need to start the server (assuming you have all
# [prerequisites](https://github.com/kkaris/depmap_analysis/blob/web-overhaul/doc/indra_depmap_service/depmap_service.rst)).
#
# Assuming you run the server with default parameters `python api.py`, you
# should have access to a POST endpoint on `http://localhost/query/submit`.
#
# Read about the available search options in the docstring of
# `IndraNetwork.handle_query()` in `depmap_analysis/indra_depmap_service/api.py`.
#
# Below we search for paths from `BRCA1` to `BRCA2` with a maximum path length
# of 4 edges (maximum allowed), `'CHEBI', 'FPLX', 'GO', 'HGNC', 'HMDB',
# 'MESH'` and `'PUBCHEM'` as allowed node namespaces and `'activation',
# 'increaseamount', 'phosphorylation'` as allowed statement types in the edges
# of the path.

# %%
import requests
from pprint import pprint
 
submit_url = 'http://localhost:5000/query/submit'
source = 'BRCA1'
target = 'BRCA2'
search_options = {'source': source,
                  'target': target,
                  'bsco': 0,
                  'fplx_expand': False,
                  'k_shortest': 3,
                  'weighted': False,
                  'simple': True,
                  'spec_len_only': False,
                  'node_filter': ['CHEBI', 'FPLX', 'GO', 'HGNC', 
                                  'HMDB', 'MESH', 'PUBCHEM'],
                  'path_length': 4,
                  'stmt_filter': ['activation',
                                  'increaseamount',
                                  'phosphorylation']
                 }

path_results = requests.post(url=submit_url, json=search_options).json()
pprint(path_results)
# Out:
# {'result': {'common_parents': {'common_parents': ['http://identifiers.org/fplx/BRCA',
#                                                   'http://identifiers.org/fplx/FANC'],
#                                'source_id': 'BRCA1',
#                                'source_ns': 'HGNC',
#                                'target_id': 'BRCA2',
#                                'target_ns': 'HGNC'},
#             'common_targets': [{'BRCA2': [[{'bs': 0.949999468559,
#                                             'evidence_count': 12,
#                                             'obj': 'BRCA2',
#                                             'stmt_hash': '33146744689149547',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.05129395906250825},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA2',
#                                             'stmt_hash': '-14152233573679567',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA2',
#                                             'stmt_hash': '30718941388306265',
#                                             'stmt_type': 'IncreaseAmount',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198}],
#                                           [{'bs': 0.949271,
#                                             'evidence_count': 4,
#                                             'obj': 'BRCA2',
#                                             'stmt_hash': '-13855379707448984',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.05206106273046052},
#                                            {'bs': 0.86,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA2',
#                                             'stmt_hash': '-13383183908194996',
#                                             'stmt_type': 'IncreaseAmount',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.1508230060136601},
#                                            {'bs': 0.86,
#                                             'evidence_count': 2,
#                                             'obj': 'BRCA2',
#                                             'stmt_hash': '-28652289181437760',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.1508230060136601},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA2',
#                                             'stmt_hash': '-141631399596680',
#                                             'stmt_type': 'IncreaseAmount',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198}]],
#                                 'lowest_highest_belief': 0.949271},
#                                {'BRCA1': [[{'bs': 0.95,
#                                             'evidence_count': 28,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '28105866281905252',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.05129339965071396},
#                                            {'bs': 0.9499999987085984,
#                                             'evidence_count': 13,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '-33750539861887060',
#                                             'stmt_type': 'IncreaseAmount',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.051293401010084144},
#                                            {'bs': 0.923,
#                                             'evidence_count': 3,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '8244323833839446',
#                                             'stmt_type': 'IncreaseAmount',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.08012615282165253},
#                                            {'bs': 0.86,
#                                             'evidence_count': 2,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '31370165811447172',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.1508230060136601},
#                                            {'bs': 0.86,
#                                             'evidence_count': 2,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '3019438726359845',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.1508230060136601},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '23688613280023705',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '-3739382798905346',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '7205811150907560',
#                                             'stmt_type': 'IncreaseAmount',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '25473625528394438',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '-17329181021319981',
#                                             'stmt_type': 'Phosphorylation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '-4746247388566927',
#                                             'stmt_type': 'Phosphorylation',
#                                             'subj': 'BRCA1',
#                                             'weight': 0.4307830699386198}],
#                                           [{'bs': 0.949271,
#                                             'evidence_count': 6,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '-34031845405068381',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.05206106273046052},
#                                            {'bs': 0.65,
#                                             'evidence_count': 1,
#                                             'obj': 'BRCA1',
#                                             'stmt_hash': '-6225955360211064',
#                                             'stmt_type': 'Activation',
#                                             'subj': 'BRCA2',
#                                             'weight': 0.4307830699386198}]],
#                                 'lowest_highest_belief': 0.949271},
#                                {'PTEN': [[{'bs': 0.86,
#                                            'evidence_count': 2,
#                                            'obj': 'PTEN',
#                                            'stmt_hash': '-22469245424128493',
#                                            'stmt_type': 'Activation',
#                                            'subj': 'BRCA1',
#                                            'weight': 0.1508230060136601}],
#                                          [{'bs': 0.65,
#                                            'evidence_count': 1,
#                                            'obj': 'PTEN',
#                                            'stmt_hash': '8590259870289126',
#                                            'stmt_type': 'Activation',
#                                            'subj': 'BRCA2',
#                                            'weight': 0.4307830699386198}]],
#                                 'lowest_highest_belief': 0.65}],
#             'paths_by_node_count': {'2': [{'path': ['BRCA1', 'BRCA2'],
#                                            'stmts': [[{'bs': 0.949999468559,
#                                                        'evidence_count': 12,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '33146744689149547',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.05129395906250825},
#                                                       {'bs': 0.65,
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-14152233573679567',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.65,
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '30718941388306265',
#                                                        'stmt_type': 'IncreaseAmount',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198}]]}],
#                                     '3': [{'path': ['BRCA1', 'Cyclin', 'BRCA2'],
#                                            'stmts': [[{'bs': 0.65,
#                                                        'evidence_count': 1,
#                                                        'obj': 'Cyclin',
#                                                        'stmt_hash': '6779917657033236',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.94999822853,
#                                                        'evidence_count': 6,
#                                                        'obj': 'Cyclin',
#                                                        'stmt_hash': '-20769781427904367',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.051295264357911874},
#                                                       {'bs': 0.65,
#                                                        'evidence_count': 1,
#                                                        'obj': 'Cyclin',
#                                                        'stmt_hash': '29572953604636021',
#                                                        'stmt_type': 'Phosphorylation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.98383,
#                                                        'evidence_count': 2,
#                                                        'obj': 'Cyclin',
#                                                        'stmt_hash': '-9558690834577969',
#                                                        'stmt_type': 'IncreaseAmount',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.016302262726565927}],
#                                                      [{'bs': 0.86,
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-869227889757510',
#                                                        'stmt_type': 'IncreaseAmount',
#                                                        'subj': 'Cyclin',
#                                                        'weight': 0.1508230060136601},
#                                                       {'bs': 0.65,
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-20200565590243375',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'Cyclin',
#                                                        'weight': 0.4307830699386198},
#                                                       {'bs': 0.98922,
#                                                        'evidence_count': 3,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '-4156594691023554',
#                                                        'stmt_type': 'Phosphorylation',
#                                                        'subj': 'Cyclin',
#                                                        'weight': 0.0108386262707474}]]},
#                                           {'path': ['BRCA1', 'PTEN', 'BRCA2'],
#                                            'stmts': [[{'bs': 0.86,
#                                                        'evidence_count': 2,
#                                                        'obj': 'PTEN',
#                                                        'stmt_hash': '-22469245424128493',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'BRCA1',
#                                                        'weight': 0.1508230060136601}],
#                                                      [{'bs': 0.65,
#                                                        'evidence_count': 1,
#                                                        'obj': 'BRCA2',
#                                                        'stmt_hash': '23780459264015764',
#                                                        'stmt_type': 'Activation',
#                                                        'subj': 'PTEN',
#                                                        'weight': 0.4307830699386198}]]}]}}}
