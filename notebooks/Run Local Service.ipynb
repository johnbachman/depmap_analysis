# %% [markdown]
# The INDRA Network Service can be used to programmatically search for paths in
# the indra network.
#
# First, you need to start the server (assuming you have all
# [prerequisites](https://github.com/indralab/depmap_analysis/blob/master/doc/indra_depmap_service/depmap_service.rst)).
#
# Assuming you run the server with default parameters `python api.py`, you
# should have access to a POST endpoint on `http://localhost/query/submit`.
#
# Read about the available search options in the docstring of
# `IndraNetwork.handle_query()` in `depmap_analysis/network_functions/indra_network.py`.
#
# Below we search for paths from `'BRCA1'` to `'BRCA2'` with `'HGNC', 'FPLX'` as allowed node namespaces and `'fplx',
# 'complex'` as ignored relation types in the edges of the path. An edge with a `'fplx'` relation is were the two agents
# either have a child/parent relation in a family and/or belong to the same complex.

# %%
import requests
from pprint import pprint
 
submit_url = 'http://127.0.0.1:5000/query/submit'
source = 'BRCA1'
target = 'BRCA2'
search_options = {'source': source, 
                  'target': target, 
                  'stmt_filter': ['fplx', 'complex'],
                  'edge_hash_blacklist': [],
                  'node_filter': ['hgnc', 'fplx'],
                  'node_blacklist': [],
                  'path_length': False,
                  'weighted': False,
                  'bsco': 0,
                  'curated_db_only': False,
                  'fplx_expand': False,
                  'two_way': False,
                  'sign': None,
                  'k_shortest': 3}

path_results = requests.post(url=submit_url, json=search_options)
if path_results.status_code == 200:
    pprint(path_results.json())
else:
    print('An error occured (%d)' % path_results.status_code)
# Out:
# {'result': {'common_parents': {'common_parents': ['http://identifiers.org/fplx/BRCA',
#                                                   'http://identifiers.org/fplx/FANC'],
#                                'source_id': '1100',
#                                'source_ns': 'HGNC',
#                                'target_id': '1101',
#                                'target_ns': 'HGNC'},
#             'common_targets': [{'CXXC1': [[{'Methylation': [{'belief': 0.86,
#                                                              'curated': False,
#                                                              'evidence_count': 2,
#                                                              'source_counts': {'sparser': 2},
#                                                              'stmt_hash': '31314112118838602',
#                                                              'stmt_type': 'Methylation',
#                                                              'weight': 0.15082288973458366}],
#                                             'obj': 'CXXC1',
#                                             'subj': 'BRCA1'}],
#                                           [{'Methylation': [{'belief': 0.65,
#                                                              'curated': False,
#                                                              'evidence_count': 1,
#                                                              'source_counts': {'sparser': 1},
#                                                              'stmt_hash': '-9895258305371176',
#                                                              'stmt_type': 'Methylation',
#                                                              'weight': 0.4307829160924542}],
#                                             'obj': 'CXXC1',
#                                             'subj': 'BRCA2'}]],
#                                 'lowest_highest_belief': 0.65},
#                                {'KIF14': [[{'DecreaseAmount': [{'belief': 0.65,
#                                                                 'curated': False,
#                                                                 'evidence_count': 1,
#                                                                 'source_counts': {'medscan': 1},
#                                                                 'stmt_hash': '-4111295740684859',
#                                                                 'stmt_type': 'DecreaseAmount',
#                                                                 'weight': 0.4307829160924542}],
#                                             'obj': 'KIF14',
#                                             'subj': 'BRCA1'}],
#                                           [{'DecreaseAmount': [{'belief': 0.65,
#                                                                 'curated': False,
#                                                                 'evidence_count': 1,
#                                                                 'source_counts': {'medscan': 1},
#                                                                 'stmt_hash': '8085354769527556',
#                                                                 'stmt_type': 'DecreaseAmount',
#                                                                 'weight': 0.4307829160924542}],
#                                             'obj': 'KIF14',
#                                             'subj': 'BRCA2'}]],
#                                 'lowest_highest_belief': 0.65},
#                                {'PRSS27': [[{'Methylation': [{'belief': 0.65,
#                                                               'curated': False,
#                                                               'evidence_count': 1,
#                                                               'source_counts': {'sparser': 1},
#                                                               'stmt_hash': '33426108852096046',
#                                                               'stmt_type': 'Methylation',
#                                                               'weight': 0.4307829160924542}],
#                                              'obj': 'PRSS27',
#                                              'subj': 'BRCA1'}],
#                                            [{'Methylation': [{'belief': 0.65,
#                                                               'curated': False,
#                                                               'evidence_count': 1,
#                                                               'source_counts': {'sparser': 1},
#                                                               'stmt_hash': '-21169539501293231',
#                                                               'stmt_type': 'Methylation',
#                                                               'weight': 0.4307829160924542}],
#                                              'obj': 'PRSS27',
#                                              'subj': 'BRCA2'}]],
#                                 'lowest_highest_belief': 0.65}],
#             'paths_by_node_count': {'backward': {},
#                                     'forward': {'2': [{'cost': '1.0000000000000000715e-18',
#                                                        'path': ['BRCA1',
#                                                                 'BRCA2'],
#                                                        'sort_key': '1.0',
#                                                        'stmts': [{'Activation': [{'belief': 0.949999985651093,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 14,
#                                                                                   'source_counts': {'reach': 14},
#                                                                                   'stmt_hash': '14631716667987313',
#                                                                                   'stmt_type': 'Activation',
#                                                                                   'weight': 0.051293309491663275},
#                                                                                  {'belief': 0.65,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 1,
#                                                                                   'source_counts': {'reach': 1},
#                                                                                   'stmt_hash': '-12566398630296749',
#                                                                                   'stmt_type': 'Activation',
#                                                                                   'weight': 0.4307829160924542}],
#                                                                   'DecreaseAmount': [{'belief': 0.65,
#                                                                                       'curated': False,
#                                                                                       'evidence_count': 1,
#                                                                                       'source_counts': {'medscan': 1},
#                                                                                       'stmt_hash': '-24434596336395778',
#                                                                                       'stmt_type': 'DecreaseAmount',
#                                                                                       'weight': 0.4307829160924542}],
#                                                                   'IncreaseAmount': [{'belief': 0.97305,
#                                                                                       'curated': False,
#                                                                                       'evidence_count': 4,
#                                                                                       'source_counts': {'medscan': 3,
#                                                                                                         'reach': 1},
#                                                                                       'stmt_hash': '19595309910344099',
#                                                                                       'stmt_type': 'IncreaseAmount',
#                                                                                       'weight': 0.027319810654962983}],
#                                                                   'Inhibition': [{'belief': 0.65,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 1,
#                                                                                   'source_counts': {'reach': 1},
#                                                                                   'stmt_hash': '30554531605300833',
#                                                                                   'stmt_type': 'Inhibition',
#                                                                                   'weight': 0.4307829160924542},
#                                                                                  {'belief': 0.9816495,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 5,
#                                                                                   'source_counts': {'medscan': 1,
#                                                                                                     'reach': 4},
#                                                                                   'stmt_hash': '17829736942076414',
#                                                                                   'stmt_type': 'Inhibition',
#                                                                                   'weight': 0.01852095898401722}],
#                                                                   'Methylation': [{'belief': 0.65,
#                                                                                    'curated': False,
#                                                                                    'evidence_count': 1,
#                                                                                    'source_counts': {'sparser': 1},
#                                                                                    'stmt_hash': '-13592368835625351',
#                                                                                    'stmt_type': 'Methylation',
#                                                                                    'weight': 0.4307829160924542}],
#                                                                   'obj': 'BRCA2',
#                                                                   'subj': 'BRCA1'}]}],
#                                                 '3': [{'cost': '0.43078291609252832958',
#                                                        'path': ['BRCA1',
#                                                                 'EGFR',
#                                                                 'BRCA2'],
#                                                        'sort_key': '0.9999999999999740628',
#                                                        'stmts': [{'Activation': [{'belief': 0.9816495,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 6,
#                                                                                   'source_counts': {'medscan': 1,
#                                                                                                     'reach': 5},
#                                                                                   'stmt_hash': '-13843381331989582',
#                                                                                   'stmt_type': 'Activation',
#                                                                                   'weight': 0.01852095898401722}],
#                                                                   'DecreaseAmount': [{'belief': 0.9419,
#                                                                                       'curated': False,
#                                                                                       'evidence_count': 3,
#                                                                                       'source_counts': {'reach': 3},
#                                                                                       'stmt_hash': '-10769750668439892',
#                                                                                       'stmt_type': 'DecreaseAmount',
#                                                                                       'weight': 0.05985616715336565},
#                                                                                      {'belief': 0.65,
#                                                                                       'curated': False,
#                                                                                       'evidence_count': 1,
#                                                                                       'source_counts': {'reach': 1},
#                                                                                       'stmt_hash': '-1678144842805492',
#                                                                                       'stmt_type': 'DecreaseAmount',
#                                                                                       'weight': 0.4307829160924542},
#                                                                                      {'belief': 0.9992299992634228,
#                                                                                       'curated': True,
#                                                                                       'evidence_count': 13,
#                                                                                       'source_counts': {'medscan': 2,
#                                                                                                         'reach': 10,
#                                                                                                         'trrust': 1},
#                                                                                       'stmt_hash': '-1736989588661343',
#                                                                                       'stmt_type': 'DecreaseAmount',
#                                                                                       'weight': 0.0007702973394103863}],
#                                                                   'IncreaseAmount': [{'belief': 0.923,
#                                                                                       'curated': False,
#                                                                                       'evidence_count': 3,
#                                                                                       'source_counts': {'reach': 3},
#                                                                                       'stmt_hash': '30869493265801776',
#                                                                                       'stmt_type': 'IncreaseAmount',
#                                                                                       'weight': 0.08012604447928486}],
#                                                                   'Inhibition': [{'belief': 0.98922,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 5,
#                                                                                   'source_counts': {'medscan': 2,
#                                                                                                     'reach': 3},
#                                                                                   'stmt_hash': '21487395686184523',
#                                                                                   'stmt_type': 'Inhibition',
#                                                                                   'weight': 0.010838525180994867}],
#                                                                   'obj': 'EGFR',
#                                                                   'subj': 'BRCA1'},
#                                                                  {'Activation': [{'belief': 0.65,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 1,
#                                                                                   'source_counts': {'reach': 1},
#                                                                                   'stmt_hash': '4837756349836381',
#                                                                                   'stmt_type': 'Activation',
#                                                                                   'weight': 0.4307829160924542}],
#                                                                   'obj': 'BRCA2',
#                                                                   'subj': 'EGFR'}]},
#                                                       {'cost': '0.86156583218490844644',
#                                                        'path': ['BRCA1',
#                                                                 'WEE1',
#                                                                 'BRCA2'],
#                                                        'sort_key': '0.87750000000000001556',
#                                                        'stmts': [{'Activation': [{'belief': 0.65,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 1,
#                                                                                   'source_counts': {'reach': 1},
#                                                                                   'stmt_hash': '-22055633946034602',
#                                                                                   'stmt_type': 'Activation',
#                                                                                   'weight': 0.4307829160924542}],
#                                                                   'obj': 'WEE1',
#                                                                   'subj': 'BRCA1'},
#                                                                  {'Inhibition': [{'belief': 0.65,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 1,
#                                                                                   'source_counts': {'reach': 1},
#                                                                                   'stmt_hash': '-12773340730259425',
#                                                                                   'stmt_type': 'Inhibition',
#                                                                                   'weight': 0.4307829160924542}],
#                                                                   'obj': 'BRCA2',
#                                                                   'subj': 'WEE1'}]}]}},
#             'timeout': False}}

# %% [markdown]
# To be able to do a signed graph search, the signed graph model checker has to be loaded to the running service. Read
# more about loading the signed graph in the
# [documenation](https://github.com/indralab/depmap_analysis/blob/master/doc/indra_depmap_service/depmap_service.rst).
# The search over the signed graph is triggered by choosing an overall sign (`'plus'` or `'minus'`) for the path between
# the source and the target with the keyword `'sign'`. In the below example we are looking for paths that have a
# positive regulation between `'SIK3'` and the `'JUN'`.

# %%
search_options['source'] = 'SIK3'
search_options['target'] = 'JUN'
search_options['sign'] = 'plus'

path_results = requests.post(url=submit_url, json=search_options)
if path_results.status_code == 200:
    pprint(path_results.json())
else:
    print('An error occured (%d)' % path_results.status_code)
# Out:
# {'result': {'common_parents': {'common_parents': [],
#                                'source_id': '29165',
#                                'source_ns': 'HGNC',
#                                'target_id': '6204',
#                                'target_ns': 'HGNC'},
#             'common_targets': [{'TLR4': [[{'Inhibition': [{'belief': 0.65,
#                                                            'curated': False,
#                                                            'evidence_count': 1,
#                                                            'source_counts': {'reach': 1},
#                                                            'stmt_hash': '-10278167144273554',
#                                                            'stmt_type': 'Inhibition',
#                                                            'weight': 0.4307829160924542}],
#                                            'obj': 'TLR4',
#                                            'subj': 'SIK3'}],
#                                          [{'Activation': [{'belief': 0.65,
#                                                            'curated': False,
#                                                            'evidence_count': 1,
#                                                            'source_counts': {'sparser': 1},
#                                                            'stmt_hash': '35706711380369404',
#                                                            'stmt_type': 'Activation',
#                                                            'weight': 0.4307829160924542}],
#                                            'obj': 'TLR4',
#                                            'subj': 'JUN'}]],
#                                 'lowest_highest_belief': 0.65},
#                                {'HDAC4': [[{'Activation': [{'belief': 0.923,
#                                                             'curated': False,
#                                                             'evidence_count': 3,
#                                                             'source_counts': {'reach': 3},
#                                                             'stmt_hash': '17900302554213114',
#                                                             'stmt_type': 'Activation',
#                                                             'weight': 0.08012604447928486}],
#                                             'Dephosphorylation': [{'belief': 0.65,
#                                                                    'curated': False,
#                                                                    'evidence_count': 1,
#                                                                    'source_counts': {'reach': 1},
#                                                                    'stmt_hash': '-13779308167251840',
#                                                                    'stmt_type': 'Dephosphorylation',
#                                                                    'weight': 0.4307829160924542}],
#                                             'Inhibition': [{'belief': 0.8775000000000001,
#                                                             'curated': False,
#                                                             'evidence_count': 2,
#                                                             'source_counts': {'reach': 1,
#                                                                               'sparser': 1},
#                                                             'stmt_hash': '-31168950003665334',
#                                                             'stmt_type': 'Inhibition',
#                                                             'weight': 0.13067832364211612}],
#                                             'Phosphorylation': [{'belief': 0.65,
#                                                                  'curated': False,
#                                                                  'evidence_count': 1,
#                                                                  'source_counts': {'reach': 1},
#                                                                  'stmt_hash': '25075975940104789',
#                                                                  'stmt_type': 'Phosphorylation',
#                                                                  'weight': 0.4307829160924542},
#                                                                 {'belief': 0.9929908146,
#                                                                  'curated': False,
#                                                                  'evidence_count': 8,
#                                                                  'source_counts': {'reach': 6,
#                                                                                    'sparser': 2},
#                                                                  'stmt_hash': '6981753707167460',
#                                                                  'stmt_type': 'Phosphorylation',
#                                                                  'weight': 0.007033865130804723},
#                                                                 {'belief': 0.65,
#                                                                  'curated': False,
#                                                                  'evidence_count': 1,
#                                                                  'source_counts': {'reach': 1},
#                                                                  'stmt_hash': '10510247562627094',
#                                                                  'stmt_type': 'Phosphorylation',
#                                                                  'weight': 0.4307829160924542}],
#                                             'obj': 'HDAC4',
#                                             'subj': 'SIK3'}],
#                                           [{'Activation': [{'belief': 0.65,
#                                                             'curated': False,
#                                                             'evidence_count': 1,
#                                                             'source_counts': {'reach': 1},
#                                                             'stmt_hash': '5348470014088652',
#                                                             'stmt_type': 'Activation',
#                                                             'weight': 0.4307829160924542}],
#                                             'obj': 'HDAC4',
#                                             'subj': 'JUN'}]],
#                                 'lowest_highest_belief': 0.65},
#                                {'CXCR4': [[{'IncreaseAmount': [{'belief': 0.65,
#                                                                 'curated': False,
#                                                                 'evidence_count': 1,
#                                                                 'source_counts': {'medscan': 1},
#                                                                 'stmt_hash': '-9335341274094456',
#                                                                 'stmt_type': 'IncreaseAmount',
#                                                                 'weight': 0.4307829160924542}],
#                                             'obj': 'CXCR4',
#                                             'subj': 'SIK3'}],
#                                           [{'Activation': [{'belief': 0.65,
#                                                             'curated': False,
#                                                             'evidence_count': 1,
#                                                             'source_counts': {'reach': 1},
#                                                             'stmt_hash': '-5431910923735912',
#                                                             'stmt_type': 'Activation',
#                                                             'weight': 0.4307829160924542}],
#                                             'obj': 'CXCR4',
#                                             'subj': 'JUN'}]],
#                                 'lowest_highest_belief': 0.65}],
#             'paths_by_node_count': {'backward': {},
#                                     'forward': {'3': [{'cost': '0.15082288973515932025',
#                                                        'path': ['SIK3',
#                                                                 'MEF2',
#                                                                 'JUN'],
#                                                        'sort_key': '0.99999999999999654454',
#                                                        'stmts': [{'Activation': [{'belief': 0.86,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 1,
#                                                                                   'source_counts': {'reach': 1},
#                                                                                   'stmt_hash': '5059390543750304',
#                                                                                   'stmt_type': 'Activation',
#                                                                                   'weight': 0.15082288973458366}],
#                                                                   'obj': 'MEF2',
#                                                                   'subj': 'SIK3'},
#                                                                  {'Activation': [{'belief': 0.99958497,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 1,
#                                                                                   'source_counts': {'reach': 1},
#                                                                                   'stmt_hash': '30717209983219282',
#                                                                                   'stmt_type': 'Activation',
#                                                                                   'weight': 0.0004151161487874783}],
#                                                                   'IncreaseAmount': [{'belief': 0.9999976723353453,
#                                                                                       'curated': False,
#                                                                                       'evidence_count': 3,
#                                                                                       'source_counts': {'medscan': 2,
#                                                                                                         'reach': 1},
#                                                                                       'stmt_hash': '-22334370715153646',
#                                                                                       'stmt_type': 'IncreaseAmount',
#                                                                                       'weight': 2.3276673637043863e-06},
#                                                                                      {'belief': 0.9994041,
#                                                                                       'curated': True,
#                                                                                       'evidence_count': 1,
#                                                                                       'source_counts': {'bel_lc': 1},
#                                                                                       'stmt_hash': '-20885668398809034',
#                                                                                       'stmt_type': 'IncreaseAmount',
#                                                                                       'weight': 0.0005960776189705841}],
#                                                                   'obj': 'JUN',
#                                                                   'subj': 'MEF2'}]},
#                                                       {'cost': '0.05024199933477793098',
#                                                        'path': ['SIK3',
#                                                                 'HDAC',
#                                                                 'JUN'],
#                                                        'sort_key': '0.9999999999997602501',
#                                                        'stmts': [{'Inhibition': [{'belief': 0.951,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 1,
#                                                                                   'source_counts': {'reach': 1},
#                                                                                   'stmt_hash': '3551537564537664',
#                                                                                   'stmt_type': 'Inhibition',
#                                                                                   'weight': 0.05024121643674679}],
#                                                                   'obj': 'HDAC',
#                                                                   'subj': 'SIK3'},
#                                                                  {'DecreaseAmount': [{'belief': 0.992999997991153,
#                                                                                       'curated': False,
#                                                                                       'evidence_count': 1,
#                                                                                       'source_counts': {'reach': 1},
#                                                                                       'stmt_hash': '-25552849577516412',
#                                                                                       'stmt_type': 'DecreaseAmount',
#                                                                                       'weight': 0.007024616959972502}],
#                                                                   'Inhibition': [{'belief': 0.9998881575,
#                                                                                   'curated': False,
#                                                                                   'evidence_count': 1,
#                                                                                   'source_counts': {'reach': 1},
#                                                                                   'stmt_hash': '11655832430750518',
#                                                                                   'stmt_type': 'Inhibition',
#                                                                                   'weight': 0.00011184875483873766}],
#                                                                   'obj': 'JUN',
#                                                                   'subj': 'HDAC'}]},
#                                                       {'cost': '0.58160580582703787385',
#                                                        'path': ['SIK3',
#                                                                 'CXCR4',
#                                                                 'JUN'],
#                                                        'sort_key': '0.95099999999999999844',
#                                                        'stmts': [{'IncreaseAmount': [{'belief': 0.65,
#                                                                                       'curated': False,
#                                                                                       'evidence_count': 1,
#                                                                                       'source_counts': {'medscan': 1},
#                                                                                       'stmt_hash': '-9335341274094456',
#                                                                                       'stmt_type': 'IncreaseAmount',
#                                                                                       'weight': 0.4307829160924542}],
#                                                                   'obj': 'CXCR4',
#                                                                   'subj': 'SIK3'},
#                                                                  {'IncreaseAmount': [{'belief': 0.86,
#                                                                                       'curated': False,
#                                                                                       'evidence_count': 2,
#                                                                                       'source_counts': {'reach': 2},
#                                                                                       'stmt_hash': '8648326662362940',
#                                                                                       'stmt_type': 'IncreaseAmount',
#                                                                                       'weight': 0.15082288973458366}],
#                                                                   'obj': 'JUN',
#                                                                   'subj': 'CXCR4'}]}]}},
#             'timeout': False}}
